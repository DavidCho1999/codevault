# %% [markdown]
# # OBC PDF Parsing with Marker
# Part 9 PDF를 Markdown으로 변환

# %%
# 1. Marker 설치 (최초 1회)
# !pip install marker-pdf -q
print('Marker installed!')

# %%
# 2. Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 경로 설정 (본인 Drive 경로에 맞게 수정)
DRIVE_PATH = '/content/drive/MyDrive/upcode-clone'
PDF_PATH = f'{DRIVE_PATH}/source/301880.pdf'
OUTPUT_PATH = f'{DRIVE_PATH}/marker_output'

# !ls -la "{PDF_PATH}" 2>/dev/null || echo '❌ PDF not found! Drive 경로 확인하세요'

# %%
# 3. GPU 확인
import torch
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
else:
    print('⚠️ GPU 없음! Runtime > Change runtime type > T4 GPU 선택')

# %%
# 4. 테스트: 9.4.2 섹션만 변환 (수식 많은 페이지)
# 페이지 718-720 = 9.4.2 Specified Loads
# !marker_single "{PDF_PATH}" \
    --page_range 718-720 \
    --output_dir /content/test_output

# 결과 확인
# !cat /content/test_output/301880/301880.md

# %%
# 5. 전체 PDF 변환 (약 10-15분 소요)
# !marker_single "{PDF_PATH}" \
    --output_dir "{OUTPUT_PATH}"

print(f'✅ 완료! 결과: {OUTPUT_PATH}')

# %%
# 6. 결과 확인
# !ls -la "{OUTPUT_PATH}/301880/"
# !head -200 "{OUTPUT_PATH}/301880/301880.md"
